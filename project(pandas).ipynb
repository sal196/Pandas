# %% [markdown]
# IMPORTING DATA

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ANALYSING DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  167 non-null    float64
#  3   Calories  163 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 5.4 KB

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110     130.0     409.1
# 1        60    117     145.0     479.0
# 2        60    103     135.0     340.0
# 3        45    109     175.0     282.4
# 4        45    117     148.0     406.0
# 5        60    102     127.0     300.0
# 6        60    110     136.0     374.0
# 7        45    104     134.0       NaN
# 8        30    109     133.0     195.1
# 9        60     98     124.0     269.0

# %%
df.sum()
# Out:
# Duration    10790.0
# Pulse       18161.0
# Maxpulse    22411.0
# Calories    61376.3
# dtype: float64

# %% [markdown]
# # REMOVING DUPLICATES

# %%
import pandas as pd
df=pd.read_csv('/content/data (5).csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# ..        ...    ...       ...       ...
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.0
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4
#
# [169 rows x 4 columns]

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# ..        ...    ...       ...       ...
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.0
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4
#
# [169 rows x 4 columns]>

# %% [markdown]
# REMOVING 'NA' values

# %%
df.isna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df.dropna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# ..        ...    ...       ...       ...
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.0
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4
#
# [161 rows x 4 columns]

# %% [markdown]
# IMPUTE/SUBSTITUTING  DATA

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# ..        ...    ...       ...       ...
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.0
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4
#
# [169 rows x 4 columns]

# %%
df.fillna('200')
# Out:
#      Duration  Pulse Maxpulse Calories
# 0          60    110    130.0    409.1
# 1          60    117    145.0    479.0
# 2          60    103    135.0    340.0
# 3          45    109    175.0    282.4
# 4          45    117    148.0    406.0
# ..        ...    ...      ...      ...
# 164        60    105    140.0    290.8
# 165        60    110    145.0    300.0
# 166        60    115    145.0    310.2
# 167        75    120    150.0    320.4
# 168        75    125    150.0    330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# VISUALIZING GIVEN DATAS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv('/content/data (5).csv')

# %%
df.plot()
